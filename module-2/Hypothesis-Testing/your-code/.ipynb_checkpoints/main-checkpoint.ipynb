# %% [markdown]
# # Before you start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas

import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents. Please, load the data using Ironhack's database (db: employees, table: employees_advanced).

# %%
# Your code here:
data = pd.read_csv('Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
# Your code here:

data.head(200)
# Out:
#                             Name  \
# 0               ALLISON,  PAUL W
# 1                BRUNO,  KEVIN D
# 2                COOPER,  JOHN E
# 3               CRESPO,  VILMA I
# 4               DOLAN,  ROBERT J
# 5               DUBERT,  TOMASZ
# 6                EDWARDS,  TIM P
# 7                ELKINS,  ERIC J
# 8               ESTRADA,  LUIS F
# 9                EWING,  MARIE A
# 10                 FINN,  SEAN P
# 11              FITCH,  JORDAN M
# 12            FREELON,  CHERYL N
# 13               GRAFF,  KEVIN M
# 14                GUNN,  ISSAC J
# 15             HARRIS,  DANIEL J
# 16              HATTULA,  CARL J
# 17               HILL,  LATINA P
# 18               HOLLER,  JOEL P
# 19              HROMA JR,  JOHN
# 20               JACKSON,  ERIC
# 21                JOYCE,  SEAN G
# 22               KING,  WARSHAW
# 23              KWONG,  NORMAN P
# 24              LEVEK,  NATHAN L
# 25                 MACK,  PAUL C
# 26             PETERS,  JOSEPH M
# ...

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
# Your code here:

data.isna().sum()
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        24775
# Annual Salary         7883
# Hourly Rate          24775
# dtype: int64

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
# Your code here:

data['Salary or Hourly'].value_counts()
# Out:
# Salary    24775
# Hourly     7883
# Name: Salary or Hourly, dtype: int64

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
# Your code here:

data.pivot_table(values = ['Name'], 
                     index = ['Department'], aggfunc=['count']).reset_index()
# Out:
#                Department  count
#                             Name
# 0            ADMIN HEARNG     38
# 1           ANIMAL CONTRL     73
# 2                AVIATION   1612
# 3       BOARD OF ELECTION    112
# 4         BOARD OF ETHICS      8
# 5           BUDGET & MGMT     44
# 6               BUILDINGS    266
# 7        BUSINESS AFFAIRS    168
# 8              CITY CLERK     85
# 9            CITY COUNCIL    400
# 10  COMMUNITY DEVELOPMENT    214
# 11                   COPA     17
# 12       CULTURAL AFFAIRS     76
# 13           DISABILITIES     29
# 14                   DoIT    101
# 15       FAMILY & SUPPORT    621
# 16                FINANCE    575
# 17                   FIRE   4800
# 18       GENERAL SERVICES    972
# 19                 HEALTH    516
# 20        HUMAN RELATIONS     17
# 21        HUMAN RESOURCES     68
# 22          INSPECTOR GEN     63
# 23                   IPRA     56
# 24                    LAW    405
# 25      LICENSE APPL COMM      1
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
hourly = data.loc[data['Salary or Hourly'] == 'Hourly']
hourly = hourly['Hourly Rate']
hourly = hourly.str.replace('$','', regex=True)
hourly = pd.to_numeric(hourly)
hourly = np.array(hourly)
hourly
# Out:
# array([14.51, 19.66, 46.1 , ..., 35.6 , 46.35, 48.85])

# %%
# H0: hourly wage = $30/hr
# H1: hourly wage <> $30/hr -- The claim

# %%
# Your code here:

from scipy.stats import ttest_1samp

stat, pval = ttest_1samp(hourly, 30)

print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval)
# Out:
# stat is   21.003532193332216
# pvalue for the two-tailed test is  2.4048011351057683e-95

# %%
# As the p value is drastically less than 0.05, we can reject H0

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our hypothesis is greater than, then to reject, the test statistic must also be positive.

# %%
police = data['Annual Salary'][(data['Department']=='POLICE')& (data['Annual Salary'].isna()==False)]
police = police.str.replace('$','', regex=True)
police = pd.to_numeric(police)
police = np.array(police)
police
# Out:
# array([104628., 111474., 104628., ...,  48078.,  87006.,  93354.])

# %%
# H0: hourly wage <= $86000
# H1: hourly wage > $86000 -- The claim

# %%
# Your code here:
stat, pval = ttest_1samp(police, 86000)

print('pvalue for the one-tailed test is ', pval/2)
# Out:
# pvalue for the one-tailed test is  2.4100985740030478e-36

# %%
# As the p value is less than 0.05, we can reject H0. The police cheif's claim is accurate

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
# Your code here:
h_rate = data.loc[data['Salary or Hourly'] == 'Hourly']
# data_crosstab = pd.crosstab(h_rate['Department'],h_rate['Salary or Hourly'], margins = True)
# data_crosstab.sort_values(by ='Hourly', ascending=False)
data_crosstab = pd.crosstab(h_rate['Department'],h_rate['Salary or Hourly'], margins = False)
data_crosstab.sort_values(by='Hourly', ascending=False)
# Out:
# Salary or Hourly       Hourly
# Department
# STREETS & SAN            1873
# WATER MGMNT              1512
# OEMC                     1212
# AVIATION                 1056
# GENERAL SERVICES          767
# TRANSPORTN                707
# FAMILY & SUPPORT          300
# PUBLIC LIBRARY            224
# CITY COUNCIL               52
# LAW                        44
# FINANCE                    43
# POLICE                     32
# ANIMAL CONTRL              16
# CULTURAL AFFAIRS           10
# BUSINESS AFFAIRS            8
# MAYOR'S OFFICE              7
# COMMUNITY DEVELOPMENT       4
# PROCUREMENT                 4
# HEALTH                      4
# CITY CLERK                  3
# FIRE                        2
# HUMAN RESOURCES             1
# BUDGET & MGMT               1
# TREASURER                   1

# %%
# Streets & San is the department with the most hourly rate

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
# Your code here:
s_s = data['Hourly Rate'][(data['Salary or Hourly']=='Hourly')& (data['Department']=='STREETS & SAN')]
s_s = s_s.str.replace('$','', regex=True)
s_s = pd.to_numeric(s_s)
s_s = np.array(s_s)
# Out:
# array([35.6 , 20.77, 35.6 , ..., 36.21, 21.43, 36.21])

# %%
# H0: hourly wage >= $35
# H1: hourly wage < $35 -- The claim

# %%
stat, pval = ttest_1samp(s_s, 35)

print('stat is  ', stat)
print('pvalue for the one-tailed test is ', pval/2)
# Out:
# stat is   -7.172610090911691
# pvalue for the one-tailed test is  5.276243152130208e-13

# %%
# As the p value is less than 0.05, we can reject H0. The average hourly wage is less than $35

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
# Your code here:
hourly = data.loc[data['Salary or Hourly'] == 'Hourly']
hourly = hourly['Hourly Rate']
hourly = hourly.str.replace('$','', regex = True)
hourly = pd.to_numeric(hourly)
hourly = np.array(hourly)
#hourly

import scipy.stats

confidence_level = 0.95
degrees_freedom = len(hourly) - 1  # or, for large values of sample size(>30), just use that
sample_mean = np.mean(hourly)
# note that we use the standard error of the sample 
# as an estimate of the standard error of the population (which is used in the theoretical formula)
sample_standard_error = scipy.stats.sem(hourly) # sem = standard error of the mean = std(mean)/sqrt(samplesize)

confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

print( 'confidence interval is ', confidence_interval, '.' )
# Out:
# confidence interval is  (32.600503194325306, 33.13588143081741) .

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
# Your code here:
police = data['Annual Salary'][(data['Department']=='POLICE')& (data['Annual Salary'].isna()==False)]
police = police.str.replace('$','', regex=True)
police = pd.to_numeric(police)
police = np.array(police)
#police

confidence_level = 0.95
degrees_freedom = len(police) - 1  # or, for large values of sample size(>30), just use that
sample_mean = np.mean(police)
# note that we use the standard error of the sample 
# as an estimate of the standard error of the population (which is used in the theoretical formula)
sample_standard_error = scipy.stats.sem(police) # sem = standard error of the mean = std(mean)/sqrt(samplesize)

confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

print( 'confidence interval is ', confidence_interval, '.' )
# Out:
# confidence interval is  (87549.78923170577, 88122.26146607645) .

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:
